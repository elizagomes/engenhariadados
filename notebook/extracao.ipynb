# %% [markdown]
# ### Imports

# %%
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
from minio import Minio
from minio.error import S3Error

# %% [markdown]
# ### Conexão PySpark

# %%
spark = SparkSession.builder \
    .appName("CSV to PostgreSQL") \
    .config("spark.driver.extraClassPath", "notebook/jar/postgresql-42.6.0.jar") \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memory", "4g") \
    .getOrCreate()

# %% [markdown]
# ### Conexão Minio

# %%
minio_endpoint = '127.0.0.1:9000'
minio_access_key = 'minioaccesskey'
minio_secret_key = 'miniosecretkey'
bucket_name = 'raw'
local_file_path = 'notebook/example.csv'
minio_object_name = 'example.csv'

minio_client = Minio(minio_endpoint, access_key=minio_access_key, secret_key=minio_secret_key, secure=False)

if not minio_client.bucket_exists(bucket_name):
    minio_client.make_bucket(bucket_name)
# Out:
# ---------------------------------------------------------------------------
# ProtocolError                             Traceback (most recent call last)
# ProtocolError: ('Connection aborted.', BadStatusLine('ÿ\x00\x00\x00\x00\x00\x00\x00\x01\x7f9\x0000\r\n'))
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# Cell In[6], line 10
#       6 minio_object_name = 'example.csv'
#       8 minio_client = Minio(minio_endpoint, access_key=minio_access_key, secret_key=minio_secret_key, secure=False)
# ---> 10 if not minio_client.bucket_exists(bucket_name):
#      11     minio_client.make_bucket(bucket_name)
#
# File /usr/local/lib/python3.11/site-packages/minio/api.py:695, in Minio.bucket_exists(self, bucket_name)
#     693 check_bucket_name(bucket_name, s3_check=self._base_url.is_aws_host)
#     694 try:
# --> 695     self._execute("HEAD", bucket_name)
#     696     return True
#     697 except S3Error as exc:
#
# File /usr/local/lib/python3.11/site-packages/minio/api.py:436, in Minio._execute(self, method, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     424 def _execute(
#     425         self,
#     426         method: str,
#    (...)
#     433         no_body_trace: bool = False,
#     434 ) -> BaseHTTPResponse:
#     435     """Execute HTTP request."""
# --> 436     region = self._get_region(bucket_name)
#     438     try:
#     439         return self._url_open(
#     440             method,
#     441             region,
#    (...)
#     448             no_body_trace=no_body_trace,
#     449         )
#
# File /usr/local/lib/python3.11/site-packages/minio/api.py:493, in Minio._get_region(self, bucket_name)
#     490     return region
#     492 # Execute GetBucketLocation REST API to get region of the bucket.
# --> 493 response = self._url_open(
#     494     "GET",
#     495     "us-east-1",
#     496     bucket_name=bucket_name,
#     497     query_params={"location": ""},
#     498 )
#     500 element = ET.fromstring(response.data.decode())
#     501 if not element.text:
#
# File /usr/local/lib/python3.11/site-packages/minio/api.py:301, in Minio._url_open(self, method, region, bucket_name, object_name, body, headers, query_params, preload_content, no_body_trace)
#     298     else:
#     299         http_headers.add(key, value)
# --> 301 response = self._http.urlopen(
#     302     method,
#     303     urlunsplit(url),
#     304     body=body,
#     305     headers=http_headers,
#     306     preload_content=preload_content,
#     307 )
#     309 if self._trace_stream:
#     310     self._trace_stream.write(f"HTTP/1.1 {response.status}\n")
#
# File /usr/local/lib/python3.11/site-packages/urllib3/poolmanager.py:444, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     442     response = conn.urlopen(method, url, **kw)
#     443 else:
# --> 444     response = conn.urlopen(method, u.request_uri, **kw)
#     446 redirect_location = redirect and response.get_redirect_location()
#     447 if not redirect_location:
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869 if not conn:
#     870     # Try again
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#     893 redirect_location = redirect and response.get_redirect_location()
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869 if not conn:
#     870     # Try again
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#     893 redirect_location = redirect and response.get_redirect_location()
#
#     [... skipping similar frames: HTTPConnectionPool.urlopen at line 874 (2 times)]
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:874, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     869 if not conn:
#     870     # Try again
#     871     log.warning(
#     872         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     873     )
# --> 874     return self.urlopen(
#     875         method,
#     876         url,
#     877         body,
#     878         headers,
#     879         retries,
#     880         redirect,
#     881         assert_same_host,
#     882         timeout=timeout,
#     883         pool_timeout=pool_timeout,
#     884         release_conn=release_conn,
#     885         chunked=chunked,
#     886         body_pos=body_pos,
#     887         preload_content=preload_content,
#     888         decode_content=decode_content,
#     889         **response_kw,
#     890     )
#     892 # Handle redirect?
#     893 redirect_location = redirect and response.get_redirect_location()
#
# File /usr/local/lib/python3.11/site-packages/urllib3/connectionpool.py:844, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841 elif isinstance(new_e, (OSError, HTTPException)):
#     842     new_e = ProtocolError("Connection aborted.", new_e)
# --> 844 retries = retries.increment(
#     845     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     846 )
#     847 retries.sleep()
#     849 # Keep track of the error for the retry warning.
#
# File /usr/local/lib/python3.11/site-packages/urllib3/util/retry.py:515, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     513 if new_retry.is_exhausted():
#     514     reason = error or ResponseError(cause)
# --> 515     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     517 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#     519 return new_retry
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=9000): Max retries exceeded with url: /raw?location= (Caused by ProtocolError('Connection aborted.', BadStatusLine('ÿ\x00\x00\x00\x00\x00\x00\x00\x01\x7f9\x0000\r\n')))
